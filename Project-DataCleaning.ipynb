# %%
import pandas as pd
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_9196\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
var=pd.read_csv("C:\\Users\\Waris Hayyat\\Desktop\\Pandas Work\\real_estate_texas_500_2024.csv")
var
# Out:
#                                                    url    status          id  \
# 0    https://www.realtor.com/realestateandhomes-det...  for_sale  9773941616
# 1    https://www.realtor.com/realestateandhomes-det...  for_sale  9224923922
# 2    https://www.realtor.com/realestateandhomes-det...  for_sale  9840661824
# 3    https://www.realtor.com/realestateandhomes-det...  for_sale  7338317229
# 4    https://www.realtor.com/realestateandhomes-det...  for_sale  7285845528
# ..                                                 ...       ...         ...
# 496  https://www.realtor.com/realestateandhomes-det...  for_sale  9697052071
# 497  https://www.realtor.com/realestateandhomes-det...  for_sale  8417528805
# 498  https://www.realtor.com/realestateandhomes-det...  for_sale  9910094492
# 499  https://www.realtor.com/realestateandhomes-det...  for_sale  9569395776
# 500  https://www.realtor.com/realestateandhomes-det...  for_sale  9434894519
#
# ...

# %%
var.isnull().sum()/ 501
# Out:
# url                0.000000
# status             0.000000
# id                 0.000000
# listPrice          0.003992
# baths              0.000000
# baths_full         0.129741
# baths_full_calc    0.129741
# beds               0.121756
# sqft               0.125749
# stories            0.219561
# sub_type           0.980040
# text               0.011976
# type               0.000000
# year_built         0.423154
# dtype: float64

# %%
var
# Out:
#                                                    url    status          id  \
# 0    https://www.realtor.com/realestateandhomes-det...  for_sale  9773941616
# 1    https://www.realtor.com/realestateandhomes-det...  for_sale  9224923922
# 2    https://www.realtor.com/realestateandhomes-det...  for_sale  9840661824
# 3    https://www.realtor.com/realestateandhomes-det...  for_sale  7338317229
# 4    https://www.realtor.com/realestateandhomes-det...  for_sale  7285845528
# ..                                                 ...       ...         ...
# 496  https://www.realtor.com/realestateandhomes-det...  for_sale  9697052071
# 497  https://www.realtor.com/realestateandhomes-det...  for_sale  8417528805
# 498  https://www.realtor.com/realestateandhomes-det...  for_sale  9910094492
# 499  https://www.realtor.com/realestateandhomes-det...  for_sale  9569395776
# 500  https://www.realtor.com/realestateandhomes-det...  for_sale  9434894519
#
# ...

# %%
var.isnull().sum()
# Out:
# url                 0
# status              0
# id                  0
# listPrice           2
# baths               0
# baths_full         65
# baths_full_calc    65
# beds               61
# sqft               63
# text                6
# type                0
# dtype: int64

# %%
var.dropna(inplace=True)

# %%
var.isnull().sum()
# Out:
# url                0
# status             0
# id                 0
# listPrice          0
# baths              0
# baths_full         0
# baths_full_calc    0
# beds               0
# sqft               0
# text               0
# type               0
# dtype: int64

# %%
var.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 427 entries, 0 to 500
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              427 non-null    object
#  1   status           427 non-null    object
#  2   id               427 non-null    int64
#  3   listPrice        427 non-null    float64
#  4   baths            427 non-null    int64
#  5   baths_full       427 non-null    float64
#  6   baths_full_calc  427 non-null    float64
#  7   beds             427 non-null    float64
#  8   sqft             427 non-null    float64
#  9   text             427 non-null    object
#  10  type             427 non-null    object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 40.0+ KB

# %%
var.describe()
# Out:
#                  id     listPrice       baths  baths_full  baths_full_calc  \
# count  4.270000e+02  4.270000e+02  427.000000  427.000000       427.000000
# mean   9.133335e+09  4.548369e+05    2.672131    2.330211         2.330211
# std    7.987596e+08  3.020361e+05    0.993049    0.760591         0.760591
# min    7.021680e+09  1.900000e+04    1.000000    1.000000         1.000000
# 25%    8.834678e+09  2.794500e+05    2.000000    2.000000         2.000000
# 50%    9.367165e+09  3.799000e+05    2.000000    2.000000         2.000000
# 75%    9.767009e+09  5.365000e+05    3.000000    3.000000         3.000000
# max    9.992374e+09  2.875000e+06    8.000000    8.000000         8.000000
#
#              beds        sqft
# count  427.000000   427.00000
# mean     3.491803  2192.98829
# std      0.851292   842.13020
# min      1.000000   500.00000
# 25%      3.000000  1604.50000
# 50%      3.000000  2036.00000
# 75%      4.000000  2635.00000
# max      9.000000  7000.00000

# %%
var
# Out:
#                                                    url    status          id  \
# 0    https://www.realtor.com/realestateandhomes-det...  for_sale  9773941616
# 1    https://www.realtor.com/realestateandhomes-det...  for_sale  9224923922
# 2    https://www.realtor.com/realestateandhomes-det...  for_sale  9840661824
# 3    https://www.realtor.com/realestateandhomes-det...  for_sale  7338317229
# 4    https://www.realtor.com/realestateandhomes-det...  for_sale  7285845528
# ..                                                 ...       ...         ...
# 494  https://www.realtor.com/realestateandhomes-det...  for_sale  8226240032
# 495  https://www.realtor.com/realestateandhomes-det...  for_sale  8207208171
# 496  https://www.realtor.com/realestateandhomes-det...  for_sale  9697052071
# 497  https://www.realtor.com/realestateandhomes-det...  for_sale  8417528805
# 500  https://www.realtor.com/realestateandhomes-det...  for_sale  9434894519
#
# ...

# %%
var.status.value_counts()
# Out:
# status
# for_sale    427
# Name: count, dtype: int64

# %%
var.type.value_counts()
# Out:
# type
# single_family    394
# mobile            12
# farm              10
# townhomes          6
# condos             5
# Name: count, dtype: int64

# %%
var.url.value_counts()
# Out:
# url
# https://www.realtor.com/realestateandhomes-detail/10410-Daw-Collins-Rd_Cleveland_TX_77328_M97739-41616           1
# https://www.realtor.com/realestateandhomes-detail/15609-Rock-Crk_Austin_TX_78734_M71897-37029                    1
# https://www.realtor.com/realestateandhomes-detail/1913-Arbor-Creek-Dr_Carrollton_TX_75010_M83268-40590           1
# https://www.realtor.com/realestateandhomes-detail/350-Co-Road-459-or-Denver-St_Ranger_TX_76470_M96853-96202      1
# https://www.realtor.com/realestateandhomes-detail/3418-Farm-Road-1896_Mount-Vernon_TX_75457_M99016-19805         1
#                                                                                                                 ..
# https://www.realtor.com/realestateandhomes-detail/406-Pecos-River-Xing_Dripping-Springs_TX_78620_M95700-23550    1
# https://www.realtor.com/realestateandhomes-detail/2003-41st-St_Lubbock_TX_79412_M89028-15660                     1
# ...

# %%
var.drop(columns=["url","status","text"],inplace=True,axis=1)

# %%
var
# Out:
#              id  listPrice  baths  baths_full  baths_full_calc  beds    sqft  \
# 0    9773941616   240000.0      2         2.0              2.0   3.0  1190.0
# 1    9224923922   379900.0      4         3.0              3.0   4.0  2033.0
# 2    9840661824   370000.0      2         2.0              2.0   4.0  2062.0
# 3    7338317229   444000.0      4         3.0              3.0   5.0  3705.0
# 4    7285845528   569000.0      2         2.0              2.0   3.0  3282.0
# ..          ...        ...    ...         ...              ...   ...     ...
# 494  8226240032   579000.0      3         3.0              3.0   5.0  2907.0
# 495  8207208171   415000.0      3         2.0              2.0   4.0  2527.0
# 496  9697052071   357707.0      2         2.0              2.0   3.0  1810.0
# 497  8417528805   340000.0      2         2.0              2.0   3.0  1438.0
# 500  9434894519   109000.0      1         1.0              1.0   3.0  1352.0
#
#               type
# 0    single_family
# ...

# %%
var.type.value_counts()
# Out:
# type
# single_family    394
# mobile            12
# farm              10
# townhomes          6
# condos             5
# Name: count, dtype: int64

# %%
var.drop(columns=["type"],inplace=True)

# %%
var
# Out:
#              id  listPrice  baths  baths_full  baths_full_calc  beds    sqft
# 0    9773941616   240000.0      2         2.0              2.0   3.0  1190.0
# 1    9224923922   379900.0      4         3.0              3.0   4.0  2033.0
# 2    9840661824   370000.0      2         2.0              2.0   4.0  2062.0
# 3    7338317229   444000.0      4         3.0              3.0   5.0  3705.0
# 4    7285845528   569000.0      2         2.0              2.0   3.0  3282.0
# ..          ...        ...    ...         ...              ...   ...     ...
# 494  8226240032   579000.0      3         3.0              3.0   5.0  2907.0
# 495  8207208171   415000.0      3         2.0              2.0   4.0  2527.0
# 496  9697052071   357707.0      2         2.0              2.0   3.0  1810.0
# 497  8417528805   340000.0      2         2.0              2.0   3.0  1438.0
# 500  9434894519   109000.0      1         1.0              1.0   3.0  1352.0
#
# [427 rows x 7 columns]

# %%
var.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 427 entries, 0 to 500
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               427 non-null    int64
#  1   listPrice        427 non-null    float64
#  2   baths            427 non-null    int64
#  3   baths_full       427 non-null    float64
#  4   baths_full_calc  427 non-null    float64
#  5   beds             427 non-null    float64
#  6   sqft             427 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 26.7 KB

# %% [markdown]
#     List price will be (x) independent variable and Sqft will be (y)dependent variable which will completely depend on x.

# %%
var.describe()
# Out:
#                  id     listPrice       baths  baths_full  baths_full_calc  \
# count  4.270000e+02  4.270000e+02  427.000000  427.000000       427.000000
# mean   9.133335e+09  4.548369e+05    2.672131    2.330211         2.330211
# std    7.987596e+08  3.020361e+05    0.993049    0.760591         0.760591
# min    7.021680e+09  1.900000e+04    1.000000    1.000000         1.000000
# 25%    8.834678e+09  2.794500e+05    2.000000    2.000000         2.000000
# 50%    9.367165e+09  3.799000e+05    2.000000    2.000000         2.000000
# 75%    9.767009e+09  5.365000e+05    3.000000    3.000000         3.000000
# max    9.992374e+09  2.875000e+06    8.000000    8.000000         8.000000
#
#              beds        sqft
# count  427.000000   427.00000
# mean     3.491803  2192.98829
# std      0.851292   842.13020
# min      1.000000   500.00000
# 25%      3.000000  1604.50000
# 50%      3.000000  2036.00000
# 75%      4.000000  2635.00000
# max      9.000000  7000.00000

# %%
var.listPrice.unique()
# Out:
# array([ 240000.,  379900.,  370000.,  444000.,  569000.,  875000.,
#         214500.,  184900.,  374900.,  199900.,  207000.,  498000.,
#         209900.,  287500.,  189900.,  150000.,  209000.,  269950.,
#         599000.,  579000.,  250000.,  236500.,  135000.,  675000.,
#         280000.,  635000.,  712500.,  395000.,  519900.,  575000.,
#          95000.,  530000.,  229900.,  115000.,  425000.,   19000.,
#         169900.,  340000.,  279900.,  669000.,  299900.,  300000.,
#         259900.,  539000.,   60000.,  610000.,  179500.,  154900.,
#         269900.,  750000.,  289000.,  400000.,  590000.,  160000.,
#         299999.,  140000.,  325000., 1199000.,  435000.,  684900.,
#         389023.,  669900.,  275000.,  470000.,  259000.,  265000.,
#         344990.,  546323.,  297515.,  315990.,  272815.,  353790.,
#         358990.,  599893.,  372014.,  293990.,  438461.,  383990.,
#         281873.,  237990.,  404629.,  338990.,  572565.,  273990.,
# ...

# %%
var.describe()
# Out:
#                  id     listPrice       baths  baths_full  baths_full_calc  \
# count  4.270000e+02  4.270000e+02  427.000000  427.000000       427.000000
# mean   9.133335e+09  4.548369e+05    2.672131    2.330211         2.330211
# std    7.987596e+08  3.020361e+05    0.993049    0.760591         0.760591
# min    7.021680e+09  1.900000e+04    1.000000    1.000000         1.000000
# 25%    8.834678e+09  2.794500e+05    2.000000    2.000000         2.000000
# 50%    9.367165e+09  3.799000e+05    2.000000    2.000000         2.000000
# 75%    9.767009e+09  5.365000e+05    3.000000    3.000000         3.000000
# max    9.992374e+09  2.875000e+06    8.000000    8.000000         8.000000
#
#              beds        sqft
# count  427.000000   427.00000
# mean     3.491803  2192.98829
# std      0.851292   842.13020
# min      1.000000   500.00000
# 25%      3.000000  1604.50000
# 50%      3.000000  2036.00000
# 75%      4.000000  2635.00000
# max      9.000000  7000.00000

# %%
var
# Out:
#      index          id  listPrice  baths  baths_full  baths_full_calc  beds  \
# 0        0  9773941616   240000.0      2         2.0              2.0   3.0
# 1        1  9224923922   379900.0      4         3.0              3.0   4.0
# 2        2  9840661824   370000.0      2         2.0              2.0   4.0
# 3        3  7338317229   444000.0      4         3.0              3.0   5.0
# 4        4  7285845528   569000.0      2         2.0              2.0   3.0
# ..     ...         ...        ...    ...         ...              ...   ...
# 422    494  8226240032   579000.0      3         3.0              3.0   5.0
# 423    495  8207208171   415000.0      3         2.0              2.0   4.0
# 424    496  9697052071   357707.0      2         2.0              2.0   3.0
# 425    497  8417528805   340000.0      2         2.0              2.0   3.0
# 426    500  9434894519   109000.0      1         1.0              1.0   3.0
#
#        sqft
# 0    1190.0
# 1    2033.0
# 2    2062.0
# ...

# %%
var
# Out:
#      index          id  listPrice  baths  baths_full  baths_full_calc  beds  \
# 0        0  9773941616   240000.0      2         2.0              2.0   3.0
# 1        1  9224923922   379900.0      4         3.0              3.0   4.0
# 2        2  9840661824   370000.0      2         2.0              2.0   4.0
# 3        3  7338317229   444000.0      4         3.0              3.0   5.0
# 4        4  7285845528   569000.0      2         2.0              2.0   3.0
# ..     ...         ...        ...    ...         ...              ...   ...
# 422    494  8226240032   579000.0      3         3.0              3.0   5.0
# 423    495  8207208171   415000.0      3         2.0              2.0   4.0
# 424    496  9697052071   357707.0      2         2.0              2.0   3.0
# 425    497  8417528805   340000.0      2         2.0              2.0   3.0
# 426    500  9434894519   109000.0      1         1.0              1.0   3.0
#
#        sqft
# 0    1190.0
# 1    2033.0
# 2    2062.0
# ...
