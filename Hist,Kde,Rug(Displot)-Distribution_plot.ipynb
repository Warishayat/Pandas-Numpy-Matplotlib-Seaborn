# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
DataSet=pd.read_csv("C:\\Users\\Waris Hayyat\\Desktop\\Machine-Learning-Model\\mediation1.csv")
DataSet
# Out:
#     Attend  Hrw  Marks
# 0       91    6     19
# 1       67    3     14
# 2       85    5     18
# 3       95    6     17
# 4       72    5     14
# 5       95    6     18
# 6       93    6     18
# 7       94    6     19
# 8       84    4     17
# 9       75    3     15
# 10      67    3     17
# 11      75    4     16
# 12      90    5     18
# 13      69    4     14
# 14      68    3     13
# 15      92    6     18
# 16      93    6     17
# 17      75    4     14
# 18      75    4     15
# 19      91    5     18

# %%
sns.catplot(data=DataSet,x="Hrw",hue="Hrw",kind="count")

# %%
                #Distribution plot for using of distribution of the data like 10lpa,3lpq,4lpa salery.
                # Use for mean data ,Range,Outliers,

# %%
#Hist_plot ----->Data in the form of bins, like o to 10lac salery bin and so on till crore.
#axis level and figure level
#Figure level is denoted by displot
#Axis
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=tips,x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips,x="total_bill",kind="hist",bins=6)

# %%
#count columns
sns.displot(data=tips,x="day",hue="sex")

# %%
titanic=sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.displot(data=titanic,x="alive",hue="sex")

# %%
#Kdeplot it is used for (kernal density) it provied us information about chances

# %%
sns.kdeplot(data=tips,x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips,x="total_bill",kind="kde",fill=True,hue="sex")

# %%
#Rugplot is used for support with some other plot as a additional information .its marginal distributing by drwaing ticks along x and y axis.

# %%
sns.kdeplot(data=tips,x="total_bill")  #it show us about distribution or density.
sns.rugplot(data=tips,x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#bivareient the histogram
sns.histplot(data=tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#again practise of distribution plot
#1:histplot
#2:kdeplot
#3:rugplot

# %%
tips=sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=tips,x="total_bill")   #it show that the bill amount betwween 10 and 20 is maximum.
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#if i want to check the maximum average were from womens or from mens then
sns.histplot(data=tips,x="total_bill",hue="sex")   #it show that the bill amount betwween 10 and 20 is maximum.
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#the same thing i can do with displot
sns.displot(data=tips,x="total_bill",kind="hist",hue="time")

# %%
#now the kdeplot it is used to show the density or problality
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.kdeplot(data=tips,x="total_bill",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#same thing with the displot

# %%
sns.displot(data=tips,x="total_bill",kind="kde",hue="time")

# %%
sns.displot(data=tips,x="total_bill",hue="day",)

# %%
#Now the rug plot thta is make in the support of other plot it show the tick on the x-axis.
sns.displot(data=tips,x="total_bill",kind="kde")
sns.rugplot(data=tips,x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#2d plot
sns.displot(data=tips,x="total_bill",y="tip",kind="kde")

# %%
#2d plot
sns.displot(data=tips,x="total_bill",y="tip",kind="hist")

# %%
sns.displot(data=tips,x="tip",kind="hist",hue="sex",element="step") #it show us the maximum tips pay by the women and men in the form of histogram.

# %%
tips.tip.value_counts()
# Out:
# tip
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: count, Length: 123, dtype: int64
