# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_10548\328324305.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
var=pd.read_csv("C:\\Users\\Waris Hayyat\\Desktop\\Pandas-Numpy Work\\loan_data.csv")
var
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %%
var.isnull().sum()
# Out:
# Loan_ID              0
# Gender               1
# Married              0
# Dependents           0
# Education            0
# Self_Employed        3
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     1
# Credit_History       1
# Property_Area        2
# Loan_Status          3
# dtype: int64

# %%
var.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            23 non-null     object
#  1   Gender             22 non-null     object
#  2   Married            23 non-null     object
#  3   Dependents         23 non-null     int64
#  4   Education          23 non-null     object
#  5   Self_Employed      20 non-null     object
#  6   ApplicantIncome    23 non-null     int64
#  7   CoapplicantIncome  23 non-null     int64
#  8   LoanAmount         23 non-null     int64
#  9   Loan_Amount_Term   22 non-null     object
#  10  Credit_History     22 non-null     object
#  11  Property_Area      21 non-null     object
#  12  Loan_Status        20 non-null     object
# dtypes: int64(4), object(9)
# memory usage: 2.5+ KB

# %%
var.dropna(inplace=True)
y=var["ApplicantIncome"]
x=var["LoanAmount"]

# %%
x=[1,2,3,4,5]
y=[12,13,14,15,16]
plt.bar(x,y,width=0.2,color="black")
plt.show()

# %%
x=['Numpy','Panda','Sckit','Tensorflow','pytorch']
y=[30,90,70,88,78]
c=["yellow","blue","red","green","black"]
plt.bar(x,y,width=0.2,color=c,edgecolor="red",label="Data-Science-Libraries")
plt.legend()
plt.xlabel("Languages")
plt.ylabel("Usage",size=12)
plt.title("Libraries Usage")
plt.show()

# %% [markdown]
#                                                                 Scatter plot

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6]
y=[11,22,33,44,55,66]

plt.scatter(x,y,color="green",edgecolor="black",label="Class-Data")
plt.colorbar()
plt.xlabel("Independent-Data")
plt.ylabel("Dependent-Data")
plt.title("Scatter-Plot")
plt.show()

# %%
x
# Out:
# 0     4583
# 1     3000
# 2     2583
# 3     6000
# 4     2333
# 5     3200
# 7     1853
# 8     1299
# 9     4950
# 11    3510
# 12    4887
# 14    7660
# 15    2600
# 17    2799
# 18    4226
# 19    1442
# Name: ApplicantIncome, dtype: int64

# %%
y
# Out:
# 0     128
# 1      66
# 2     120
# 3     141
# 4      95
# 5      70
# 7     114
# 8      17
# 9     125
# 11     76
# 12    133
# 14    104
# 15    116
# 17    122
# 18    110
# 19     35
# Name: LoanAmount, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(x,y,width=5,edgecolor="black",color="green",label="Loan-Data")
plt.legend()
plt.xlabel("loan_amount(Lac)")
plt.ylabel("Income(Thousand")
plt.title("Loan-Pridiction")
plt.show()

# %% [markdown]
#                                                          Now for scatter

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y,color="red",edgecolor="black",label="Loan_Data",linewidth=0.5)
plt.legend()
plt.xlabel("loan_Amount in LAC")
plt.ylabel("Salery")
plt.title("Scatter-plot")
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Waris Hayyat\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\pyplot.py'>
