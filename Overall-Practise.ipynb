# %%
import pandas as pd
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_4484\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
var=pd.read_csv("C:\\Users\\Waris Hayyat\\Desktop\\Pandas Work\\loan_data1.csv")
var
# Out:
#      Loan_ID  Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0   LP001003         1.0           4583.0             1508.0       128.0
# 1   LP001005         0.0           3000.0                0.0        66.0
# 2   LP001006         0.0           2583.0             2358.0       120.0
# 3   LP001008         0.0           6000.0                0.0       141.0
# 4   LP001013         0.0           2333.0             1516.0        95.0
# 5   LP001024         2.0           3200.0              700.0        70.0
# 6   LP001027         2.0           2500.0             1840.0       109.0
# 7   LP001029         0.0           1853.0             2840.0       114.0
# 8   LP001030         2.0           1299.0             1086.0        17.0
# 9   LP001032         0.0           4950.0                NaN       125.0
# 10  LP001034         1.0           3596.0                NaN       100.0
# 11  LP001036         0.0           3510.0                NaN        76.0
# ...

# %%
var.loc[20,"Loan_ID"]= "LP00129"
var
# Out:
#      Loan_ID  Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0   LP001003         1.0           4583.0             1508.0       128.0
# 1   LP001005         0.0           3000.0                0.0        66.0
# 2   LP001006         0.0           2583.0             2358.0       120.0
# 3   LP001008         0.0           6000.0                0.0       141.0
# 4   LP001013         0.0           2333.0             1516.0        95.0
# 5   LP001024         2.0           3200.0              700.0        70.0
# 6   LP001027         2.0           2500.0             1840.0       109.0
# 7   LP001029         0.0           1853.0             2840.0       114.0
# 8   LP001030         2.0           1299.0             1086.0        17.0
# 9   LP001032         0.0           4950.0                NaN       125.0
# 10  LP001034         1.0           3596.0                NaN       100.0
# 11  LP001036         0.0           3510.0                NaN        76.0
# ...

# %%
var.interpolate(method="linear")
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_4484\906631510.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(method="linear")
#      Loan_ID  Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0   LP001003         1.0           4583.0        1508.000000       128.0
# 1   LP001005         0.0           3000.0           0.000000        66.0
# 2   LP001006         0.0           2583.0        2358.000000       120.0
# 3   LP001008         0.0           6000.0           0.000000       141.0
# 4   LP001013         0.0           2333.0        1516.000000        95.0
# 5   LP001024         2.0           3200.0         700.000000        70.0
# 6   LP001027         2.0           2500.0        1840.000000       109.0
# 7   LP001029         0.0           1853.0        2840.000000       114.0
# ...

# %%
var.fillna({
    "Loan_Amount_Term":"00",
    "Credit_History":"1",
})
# Out:
#   Cell In[34], line 4
#     inplace=True
#           ^
# SyntaxError: ':' expected after dictionary key

# %%
# Out:
#   Cell In[18], line 1
#     var.skiprows()=21
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
# Out:
#      Loan_ID  Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0   LP001003         1.0           4583.0             1508.0       128.0
# 1   LP001005         0.0           3000.0                0.0        66.0
# 2   LP001006         0.0           2583.0             2358.0       120.0
# 3   LP001008         0.0           6000.0                0.0       141.0
# 4   LP001013         0.0           2333.0             1516.0        95.0
# 5   LP001024         2.0           3200.0              700.0        70.0
# 6   LP001027         2.0           2500.0             1840.0       109.0
# 7   LP001029         0.0           1853.0             2840.0       114.0
# 8   LP001030         2.0           1299.0             1086.0        17.0
# 9   LP001032         0.0           4950.0                NaN       125.0
# 10  LP001034         1.0           3596.0                NaN       100.0
# 11  LP001036         0.0           3510.0                NaN        76.0
# ...

# %%
var.fillna({
    "Loan_Amount_Term":"00",
    "Credit_History":"1"
})
var.inplace=True

# %%
var.replace(to_replace="Urban",value=0)
# Out:
#      Loan_ID  Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0   LP001003         1.0           4583.0             1508.0       128.0
# 1   LP001005         0.0           3000.0                0.0        66.0
# 2   LP001006         0.0           2583.0             2358.0       120.0
# 3   LP001008         0.0           6000.0                0.0       141.0
# 4   LP001013         0.0           2333.0             1516.0        95.0
# 5   LP001024         2.0           3200.0              700.0        70.0
# 6   LP001027         2.0           2500.0             1840.0       109.0
# 7   LP001029         0.0           1853.0             2840.0       114.0
# 8   LP001030         2.0           1299.0             1086.0        17.0
# 9   LP001032         0.0           4950.0                NaN       125.0
# 10  LP001034         1.0           3596.0                NaN       100.0
# 11  LP001036         0.0           3510.0                NaN        76.0
# ...

# %%
var.fillna("00",inplace=True)
var
# Out:
#      Loan_ID Dependents ApplicantIncome CoapplicantIncome LoanAmount  \
# 0   LP001003        1.0          4583.0            1508.0      128.0
# 1   LP001005        0.0          3000.0               0.0       66.0
# 2   LP001006        0.0          2583.0            2358.0      120.0
# 3   LP001008        0.0          6000.0               0.0      141.0
# 4   LP001013        0.0          2333.0            1516.0       95.0
# 5   LP001024        2.0          3200.0             700.0       70.0
# 6   LP001027        2.0          2500.0            1840.0      109.0
# 7   LP001029        0.0          1853.0            2840.0      114.0
# 8   LP001030        2.0          1299.0            1086.0       17.0
# 9   LP001032        0.0          4950.0                00      125.0
# 10  LP001034        1.0          3596.0                00      100.0
# 11  LP001036        0.0          3510.0                00       76.0
# 12  LP001038        0.0          4887.0                00      133.0
# ...

# %%
var.replace(to_replace="Urban",value="360",inplace=True)
var
# Out:
#      Loan_ID Dependents ApplicantIncome CoapplicantIncome LoanAmount  \
# 0   LP001003        1.0          4583.0            1508.0      128.0
# 1   LP001005        0.0          3000.0               0.0       66.0
# 2   LP001006        0.0          2583.0            2358.0      120.0
# 3   LP001008        0.0          6000.0               0.0      141.0
# 4   LP001013        0.0          2333.0            1516.0       95.0
# 5   LP001024        2.0          3200.0             700.0       70.0
# 6   LP001027        2.0          2500.0            1840.0      109.0
# 7   LP001029        0.0          1853.0            2840.0      114.0
# 8   LP001030        2.0          1299.0            1086.0       17.0
# 9   LP001032        0.0          4950.0                00      125.0
# 10  LP001034        1.0          3596.0                00      100.0
# 11  LP001036        0.0          3510.0                00       76.0
# 12  LP001038        0.0          4887.0                00      133.0
# ...

# %%
var.replace(to_replace="N",value="1",inplace=True)

# %%
var
# Out:
#      Loan_ID Dependents ApplicantIncome CoapplicantIncome LoanAmount  \
# 0   LP001003        1.0          4583.0            1508.0      128.0
# 1   LP001005        0.0          3000.0               0.0       66.0
# 2   LP001006        0.0          2583.0            2358.0      120.0
# 3   LP001008        0.0          6000.0               0.0      141.0
# 4   LP001013        0.0          2333.0            1516.0       95.0
# 5   LP001024        2.0          3200.0             700.0       70.0
# 6   LP001027        2.0          2500.0            1840.0      109.0
# 7   LP001029        0.0          1853.0            2840.0      114.0
# 8   LP001030        2.0          1299.0            1086.0       17.0
# 9   LP001032        0.0          4950.0                00      125.0
# 10  LP001034        1.0          3596.0                00      100.0
# 11  LP001036        0.0          3510.0                00       76.0
# 12  LP001038        0.0          4887.0                00      133.0
# ...
