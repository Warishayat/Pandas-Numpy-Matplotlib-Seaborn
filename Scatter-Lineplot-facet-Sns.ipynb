# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as xp

# %%
var=pd.read_csv("mediation1.csv")
var
# Out:
#     Attend  Hrw  Marks
# 0       91    6     19
# 1       67    3     14
# 2       85    5     18
# 3       95    6     17
# 4       72    5     14
# 5       95    6     18
# 6       93    6     18
# 7       94    6     19
# 8       84    4     17
# 9       75    3     15
# 10      67    3     17
# 11      75    4     16
# 12      90    5     18
# 13      69    4     14
# 14      68    3     13
# 15      92    6     18
# 16      93    6     17
# 17      75    4     14
# 18      75    4     15
# 19      91    5     18

# %%
sns.scatterplot(data=var,x=var["Hrw"],y=var["Marks"])
# Out:
# <Axes: xlabel='Hrw', ylabel='Marks'>

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
x=df["total_bill"]
y=df["tip"]

# %% [markdown]
#                 Figure level plot and axis level plot

# %%
sns.scatterplot(data=df,x=x,y=y,hue="sex",style="time",size="size")    #axis -plot
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=df,x=x,y=y,kind="scatter",hue="sex",style="time",size="size")         #Rel-plot

# %% [markdown]
#                 #Line_Plot(if we want to show continuety we will show the data into in the line plot)

# %%
world=xp.data.gapminder()
world
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
#now we want to check the live capcitency of pakistan

# %%
temp=world[world["country"]=="Pakistan"]
temp
# Out:
#        country continent  year  lifeExp        pop    gdpPercap iso_alpha  \
# 1164  Pakistan      Asia  1952   43.436   41346560   684.597144       PAK
# 1165  Pakistan      Asia  1957   45.557   46679944   747.083529       PAK
# 1166  Pakistan      Asia  1962   47.670   53100671   803.342742       PAK
# 1167  Pakistan      Asia  1967   49.800   60641899   942.408259       PAK
# 1168  Pakistan      Asia  1972   51.929   69325921  1049.938981       PAK
# 1169  Pakistan      Asia  1977   54.043   78152686  1175.921193       PAK
# 1170  Pakistan      Asia  1982   56.158   91462088  1443.429832       PAK
# 1171  Pakistan      Asia  1987   58.245  105186881  1704.686583       PAK
# 1172  Pakistan      Asia  1992   60.838  120065004  1971.829464       PAK
# 1173  Pakistan      Asia  1997   61.818  135564834  2049.350521       PAK
# 1174  Pakistan      Asia  2002   63.610  153403524  2092.712441       PAK
# 1175  Pakistan      Asia  2007   65.483  169270617  2605.947580       PAK
#
# ...

# %%
#axis level
sns.lineplot(data=temp,x="year",y="lifeExp")
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
#relplot
sns.relplot(data=temp,x="year",y="lifeExp",kind="line")

# %%
asia=world[world["country"].isin(["India","Pakistan","Germany"])]
asia
# Out:
#        country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 564    Germany    Europe  1952   67.500    69145952   7144.114393       DEU
# 565    Germany    Europe  1957   69.100    71019069  10187.826650       DEU
# 566    Germany    Europe  1962   70.300    73739117  12902.462910       DEU
# 567    Germany    Europe  1967   70.800    76368453  14745.625610       DEU
# 568    Germany    Europe  1972   71.000    78717088  18016.180270       DEU
# 569    Germany    Europe  1977   72.500    78160773  20512.921230       DEU
# 570    Germany    Europe  1982   73.800    78335266  22031.532740       DEU
# 571    Germany    Europe  1987   74.847    77718298  24639.185660       DEU
# 572    Germany    Europe  1992   76.070    80597764  26505.303170       DEU
# 573    Germany    Europe  1997   77.340    82011073  27788.884160       DEU
# 574    Germany    Europe  2002   78.670    82350671  30035.801980       DEU
# ...

# %%
sns.relplot(data=asia,x="year",y="lifeExp",kind="line",hue="country",style="continent",size="continent")

# %%
#facetplot from one plot to multiple plot it will work  with rel plot but it will not work with axisplot,line acatter and lineplot

# %%
df
sns.relplot(data=df,x="total_bill",y="tip",col="sex",row="day",kind="line")

# %%
sdataset=sns.load_dataset("tips")
sns.scatterplot(data=dataset,x="total_bill",y="tip",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sdataset=sns.load_dataset("tips")
sns.lineplot(data=dataset,x="total_bill",y="tip",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=dataset,x="total_bill",y="tip",hue="sex",col="sex")

# %%
world_data=xp.data.gapminder()
world_data
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
Amercia=world_data[world_data["country"]=="Turkey"]
Amercia
# Out:
#      country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 1572  Turkey    Europe  1952   43.585  22235677  1969.100980       TUR
# 1573  Turkey    Europe  1957   48.079  25670939  2218.754257       TUR
# 1574  Turkey    Europe  1962   52.098  29788695  2322.869908       TUR
# 1575  Turkey    Europe  1967   54.336  33411317  2826.356387       TUR
# 1576  Turkey    Europe  1972   57.005  37492953  3450.696380       TUR
# 1577  Turkey    Europe  1977   59.507  42404033  4269.122326       TUR
# 1578  Turkey    Europe  1982   61.036  47328791  4241.356344       TUR
# 1579  Turkey    Europe  1987   63.108  52881328  5089.043686       TUR
# 1580  Turkey    Europe  1992   66.146  58179144  5678.348271       TUR
# 1581  Turkey    Europe  1997   68.835  63047647  6601.429915       TUR
# 1582  Turkey    Europe  2002   70.845  67308928  6508.085718       TUR
# 1583  Turkey    Europe  2007   71.777  71158647  8458.276384       TUR
#
#       iso_num
# 1572      792
# ...

# %%
sns.lineplot(data=Amercia,x="year",y="lifeExp")
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
Europe_Asia=world_data[world_data["country"].isin(["Pakistan","China","France"])]
Europe_Asia
# Out:
#        country continent  year   lifeExp         pop     gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527    400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000    575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000    487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000    612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000    676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000    741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000    962.421381       CHN
# 295      China      Asia  1987  67.27400  1084035000   1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000   1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000   2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000   3119.280896       CHN
# ...

# %%
sns.relplot(data=Europe_Asia,x="year",y="lifeExp",kind="line",hue="country",size="country")
