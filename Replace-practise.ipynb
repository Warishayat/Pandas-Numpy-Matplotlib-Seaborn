# %%
import pandas as pd
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_2368\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
r=pd.read_csv("C:\\Users\Waris Hayyat\\Desktop\\Pandas Work\\loan_data1.csv")
r
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_2368\1049469624.py:1: SyntaxWarning: invalid escape sequence '\W'
#   r=pd.read_csv("C:\\Users\Waris Hayyat\\Desktop\\Pandas Work\\loan_data1.csv")
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes         1.0      Graduate            No
# 1   LP001005    Male     Yes         0.0      Graduate           Yes
# 2   LP001006    Male     Yes         0.0  Not Graduate            No
# 3   LP001008    Male      No         0.0      Graduate            No
# 4   LP001013    Male     Yes         0.0  Not Graduate            No
# 5   LP001024    Male     Yes         2.0      Graduate            No
# 6   LP001027    Male     Yes         2.0      Graduate           NaN
# 7   LP001029    Male      No         0.0      Graduate            No
# ...

# %%
r.replace(to_replace="360",value="1")
r
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes         1.0      Graduate            No
# 1   LP001005    Male     Yes         0.0      Graduate           Yes
# 2   LP001006    Male     Yes         0.0  Not Graduate            No
# 3   LP001008    Male      No         0.0      Graduate            No
# 4   LP001013    Male     Yes         0.0  Not Graduate            No
# 5   LP001024    Male     Yes         2.0      Graduate            No
# 6   LP001027    Male     Yes         2.0      Graduate           NaN
# 7   LP001029    Male      No         0.0      Graduate            No
# 8   LP001030    Male     Yes         2.0      Graduate            No
# 9   LP001032    Male      No         0.0      Graduate            No
# 10  LP001034    Male      No         1.0  Not Graduate            No
# 11  LP001036  Female      No         0.0      Graduate            No
# 12  LP001038    Male     Yes         0.0  Not Graduate            No
# ...

# %%
r.replace("[A-Z,a-z]","python",regex=True)
# Out:
#                Loan_ID                                Gender  \
# 0   pythonpython001003              pythonpythonpythonpython
# 1   pythonpython001005              pythonpythonpythonpython
# 2   pythonpython001006              pythonpythonpythonpython
# 3   pythonpython001008              pythonpythonpythonpython
# 4   pythonpython001013              pythonpythonpythonpython
# 5   pythonpython001024              pythonpythonpythonpython
# 6   pythonpython001027              pythonpythonpythonpython
# 7   pythonpython001029              pythonpythonpythonpython
# 8   pythonpython001030              pythonpythonpythonpython
# 9   pythonpython001032              pythonpythonpythonpython
# 10  pythonpython001034              pythonpythonpythonpython
# 11  pythonpython001036  pythonpythonpythonpythonpythonpython
# 12  pythonpython001038              pythonpythonpythonpython
# 13  pythonpython001041              pythonpythonpythonpython
# ...

# %%
r.replace({"Gender":"[A-Z,a-z]"},22,regex=True)
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_2368\2931942202.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   r.replace({"Gender":"[A-Z,a-z]"},22,regex=True)
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    22.0     Yes         1.0      Graduate            No
# 1   LP001005    22.0     Yes         0.0      Graduate           Yes
# 2   LP001006    22.0     Yes         0.0  Not Graduate            No
# 3   LP001008    22.0      No         0.0      Graduate            No
# 4   LP001013    22.0     Yes         0.0  Not Graduate            No
# 5   LP001024    22.0     Yes         2.0      Graduate            No
# 6   LP001027    22.0     Yes         2.0      Graduate           NaN
# ...

# %%
r.replace("1","360")
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes         1.0      Graduate            No
# 1   LP001005    Male     Yes         0.0      Graduate           Yes
# 2   LP001006    Male     Yes         0.0  Not Graduate            No
# 3   LP001008    Male      No         0.0      Graduate            No
# 4   LP001013    Male     Yes         0.0  Not Graduate            No
# 5   LP001024    Male     Yes         2.0      Graduate            No
# 6   LP001027    Male     Yes         2.0      Graduate           NaN
# 7   LP001029    Male      No         0.0      Graduate            No
# 8   LP001030    Male     Yes         2.0      Graduate            No
# 9   LP001032    Male      No         0.0      Graduate            No
# 10  LP001034    Male      No         1.0  Not Graduate            No
# 11  LP001036  Female      No         0.0      Graduate            No
# 12  LP001038    Male     Yes         0.0  Not Graduate            No
# ...

# %%
r.replace("1",method="ffill")
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_2368\3283945173.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   r.replace("1",method="ffill")
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes         1.0      Graduate            No
# 1   LP001005    Male     Yes         0.0      Graduate           Yes
# 2   LP001006    Male     Yes         0.0  Not Graduate            No
# 3   LP001008    Male      No         0.0      Graduate            No
# 4   LP001013    Male     Yes         0.0  Not Graduate            No
# 5   LP001024    Male     Yes         2.0      Graduate            No
# 6   LP001027    Male     Yes         2.0      Graduate           NaN
# 7   LP001029    Male      No         0.0      Graduate            No
# 8   LP001030    Male     Yes         2.0      Graduate            No
# ...

# %%
r.replace("1",method="bfill")
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_2368\3615487833.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   r.replace("1",method="bfill")
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes         1.0      Graduate            No
# 1   LP001005    Male     Yes         0.0      Graduate           Yes
# 2   LP001006    Male     Yes         0.0  Not Graduate            No
# 3   LP001008    Male      No         0.0      Graduate            No
# 4   LP001013    Male     Yes         0.0  Not Graduate            No
# 5   LP001024    Male     Yes         2.0      Graduate            No
# 6   LP001027    Male     Yes         2.0      Graduate           NaN
# 7   LP001029    Male      No         0.0      Graduate            No
# 8   LP001030    Male     Yes         2.0      Graduate            No
# ...

# %%
r.replace("1",method="ffill",limit=2)
# Out:
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_2368\3195519868.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   r.replace("1",method="ffill",limit=2)
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes         1.0      Graduate            No
# 1   LP001005    Male     Yes         0.0      Graduate           Yes
# 2   LP001006    Male     Yes         0.0  Not Graduate            No
# 3   LP001008    Male      No         0.0      Graduate            No
# 4   LP001013    Male     Yes         0.0  Not Graduate            No
# 5   LP001024    Male     Yes         2.0      Graduate            No
# 6   LP001027    Male     Yes         2.0      Graduate           NaN
# 7   LP001029    Male      No         0.0      Graduate            No
# 8   LP001030    Male     Yes         2.0      Graduate            No
# ...

# %%
r
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes         1.0      Graduate            No
# 1   LP001005    Male     Yes         0.0      Graduate           Yes
# 2   LP001006    Male     Yes         0.0  Not Graduate            No
# 3   LP001008    Male      No         0.0      Graduate            No
# 4   LP001013    Male     Yes         0.0  Not Graduate            No
# 5   LP001024    Male     Yes         2.0      Graduate            No
# 6   LP001027    Male     Yes         2.0      Graduate           NaN
# 7   LP001029    Male      No         0.0      Graduate            No
# 8   LP001030    Male     Yes         2.0      Graduate            No
# 9   LP001032    Male      No         0.0      Graduate            No
# 10  LP001034    Male      No         1.0  Not Graduate            No
# 11  LP001036  Female      No         0.0      Graduate            No
# 12  LP001038    Male     Yes         0.0  Not Graduate            No
# ...

# %%
r.dropna(inplace=True)
r
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes         1.0      Graduate            No
# 1   LP001005    Male     Yes         0.0      Graduate           Yes
# 2   LP001006    Male     Yes         0.0  Not Graduate            No
# 3   LP001008    Male      No         0.0      Graduate            No
# 4   LP001013    Male     Yes         0.0  Not Graduate            No
# 5   LP001024    Male     Yes         2.0      Graduate            No
# 7   LP001029    Male      No         0.0      Graduate            No
# 8   LP001030    Male     Yes         2.0      Graduate            No
# 9   LP001032    Male      No         0.0      Graduate            No
# 11  LP001036  Female      No         0.0      Graduate            No
# 12  LP001038    Male     Yes         0.0  Not Graduate            No
# 14  LP001043    Male     Yes         0.0  Not Graduate            No
# 15  LP001047    Male     Yes         0.0  Not Graduate            No
# ...
