# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd

# %%
df=pd.read_csv("/kaggle/input/52000-animation-movie-details-dataset-2024/Animation_Movies.csv")
df
# Out:
#            id                                              title  \
# 0      150540                                         Inside Out
# 1       14160                                                 Up
# 2          12                                       Finding Nemo
# 3      354912                                               Coco
# 4       10681                                             WALL·E
# ...       ...                                                ...
# 51940  656677                                          Белозубка
# 51941  657149                     Shimajiro to Ururu no Heroland
# 51942  656945                  Robo Force: The Revenge of Nazgar
# 51943  656893  Beginning Responsibility: A Lunchroom Goes Ban...
# 51944  656966                                  Natural Selection
#
#        vote_average  vote_count    status release_date    revenue  runtime  \
# 0             7.922       19463  Released   2015-06-09  857611174       95
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# title                       1
# vote_average                0
# vote_count                  0
# status                      0
# release_date             2137
# revenue                     0
# runtime                     0
# adult                       0
# backdrop_path           36110
# budget                      0
# homepage                43692
# imdb_id                 22393
# original_language           0
# original_title              1
# overview                 6079
# popularity                  0
# poster_path             14011
# tagline                 47267
# genres                      0
# production_companies    22547
# production_countries    12245
# spoken_languages        18127
# dtype: int64

# %%
df.shape[0]
# Out:
# 51945

# %%
df.isnull().sum()/df.shape[0]
# Out:
# id                      0.000000
# title                   0.000019
# vote_average            0.000000
# vote_count              0.000000
# status                  0.000000
# release_date            0.041140
# revenue                 0.000000
# runtime                 0.000000
# adult                   0.000000
# backdrop_path           0.695158
# budget                  0.000000
# homepage                0.841120
# imdb_id                 0.431091
# original_language       0.000000
# original_title          0.000019
# overview                0.117028
# popularity              0.000000
# poster_path             0.269728
# tagline                 0.909943
# genres                  0.000000
# production_companies    0.434055
# production_countries    0.235730
# spoken_languages        0.348965
# dtype: float64

# %% [markdown]
# We will delet the columns that have the null value more then 20%.

# %%
df.drop(columns=["production_companies","spoken_languages","imdb_id","homepage","poster_path","tagline"],inplace=True)

# %%
df
# Out:
#            id                                              title  \
# 0      150540                                         Inside Out
# 1       14160                                                 Up
# 2          12                                       Finding Nemo
# 3      354912                                               Coco
# 4       10681                                             WALL·E
# ...       ...                                                ...
# 51940  656677                                          Белозубка
# 51941  657149                     Shimajiro to Ururu no Heroland
# 51942  656945                  Robo Force: The Revenge of Nazgar
# 51943  656893  Beginning Responsibility: A Lunchroom Goes Ban...
# 51944  656966                                  Natural Selection
#
#        vote_average  vote_count    status release_date    revenue  runtime  \
# 0             7.922       19463  Released   2015-06-09  857611174       95
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# title                       1
# vote_average                0
# vote_count                  0
# status                      0
# release_date             2137
# revenue                     0
# runtime                     0
# adult                       0
# backdrop_path           36110
# budget                      0
# original_language           0
# original_title              1
# overview                 6079
# popularity                  0
# genres                      0
# production_countries    12245
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]
# Out:
# id                      0.000000
# title                   0.000019
# vote_average            0.000000
# vote_count              0.000000
# status                  0.000000
# release_date            0.041140
# revenue                 0.000000
# runtime                 0.000000
# adult                   0.000000
# backdrop_path           0.695158
# budget                  0.000000
# original_language       0.000000
# original_title          0.000019
# overview                0.117028
# popularity              0.000000
# genres                  0.000000
# production_countries    0.235730
# dtype: float64

# %%
df.drop(columns=["backdrop_path"],inplace=True)

# %%
df
# Out:
#            id                                              title  \
# 0      150540                                         Inside Out
# 1       14160                                                 Up
# 2          12                                       Finding Nemo
# 3      354912                                               Coco
# 4       10681                                             WALL·E
# ...       ...                                                ...
# 51940  656677                                          Белозубка
# 51941  657149                     Shimajiro to Ururu no Heroland
# 51942  656945                  Robo Force: The Revenge of Nazgar
# 51943  656893  Beginning Responsibility: A Lunchroom Goes Ban...
# 51944  656966                                  Natural Selection
#
#        vote_average  vote_count    status release_date    revenue  runtime  \
# 0             7.922       19463  Released   2015-06-09  857611174       95
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# title                       1
# vote_average                0
# vote_count                  0
# status                      0
# release_date             2137
# revenue                     0
# runtime                     0
# adult                       0
# budget                      0
# original_language           0
# original_title              1
# overview                 6079
# popularity                  0
# genres                      0
# production_countries    12245
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#            id                           title  vote_average  vote_count  \
# 0      150540                      Inside Out         7.922       19463
# 1       14160                              Up         7.949       18857
# 2          12                    Finding Nemo         7.824       18061
# 3      354912                            Coco         8.222       17742
# 4       10681                          WALL·E         8.078       17446
# ...       ...                             ...           ...         ...
# 51934  657684     Story of the Christmas Toys         0.000           0
# 51935  657512                     The Longing         0.000           0
# 51939  656671                        Migrante         0.000           0
# 51941  657149  Shimajiro to Ururu no Heroland         0.000           0
# 51944  656966               Natural Selection         0.000           0
#
#          status release_date    revenue  runtime  adult     budget  \
# ...

# %%
df.isnull().sum()
# Out:
# id                      0
# title                   0
# vote_average            0
# vote_count              0
# status                  0
# release_date            0
# revenue                 0
# runtime                 0
# adult                   0
# budget                  0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# genres                  0
# production_countries    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35107 entries, 0 to 51944
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    35107 non-null  int64
#  1   title                 35107 non-null  object
#  2   vote_average          35107 non-null  float64
#  3   vote_count            35107 non-null  int64
#  4   status                35107 non-null  object
#  5   release_date          35107 non-null  object
#  6   revenue               35107 non-null  int64
#  7   runtime               35107 non-null  int64
#  8   adult                 35107 non-null  bool
#  9   budget                35107 non-null  int64
#  10  original_language     35107 non-null  object
#  11  original_title        35107 non-null  object
#  12  overview              35107 non-null  object
#  13  popularity            35107 non-null  float64
#  14  genres                35107 non-null  object
# ...

# %%
df.id.value_counts()
# Out:
# id
# 150540     1
# 989841     1
# 1178491    1
# 990308     1
# 1178471    1
#           ..
# 161921     1
# 161919     1
# 161858     1
# 161859     1
# 656966     1
# Name: count, Length: 35107, dtype: int64

# %%
df.title.value_counts()
# Out:
# title
# Cinderella                11
# Thumbelina                 9
# Little Red Riding Hood     9
# The Ugly Duckling          9
# A Christmas Carol          8
#                           ..
# Oh! My Sex Goddess         1
# KJFG No.5                  1
# Last Summer                1
# Dragon Knight              1
# Natural Selection          1
# Name: count, Length: 33563, dtype: int64

# %%
df.describe()
