# %%
import pandas as pd

# %%
var=pd.read_csv("C:\\Users\Waris Hayyat\\Desktop\\Pandas Work\\loan_data1.csv")
var
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\Waris Hayyat\AppData\Local\Temp\ipykernel_11148\2694262972.py:1: SyntaxWarning: invalid escape sequence '\W'
#   var=pd.read_csv("C:\\Users\Waris Hayyat\\Desktop\\Pandas Work\\loan_data1.csv")
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# ...

# %% [markdown]
#                                                                     Dropna and their functions

# %%
# var.dropna()
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# 14  LP001043    Male     Yes           0  Not Graduate            No
# 15  LP001047    Male     Yes           0  Not Graduate            No
# ...

# %% [markdown]
#                                                         Drop Na value in rows

# %%
# var.dropna(axis=0)
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# 14  LP001043    Male     Yes           0  Not Graduate            No
# 15  LP001047    Male     Yes           0  Not Graduate            No
# ...

# %% [markdown]
#                                                             Drop Na value from columns

# %%
# var.dropna(axis=1)
# Out:
#      Loan_ID Married  Dependents     Education  ApplicantIncome  \
# 0   LP001003     Yes           1      Graduate             4583
# 1   LP001005     Yes           0      Graduate             3000
# 2   LP001006     Yes           0  Not Graduate             2583
# 3   LP001008      No           0      Graduate             6000
# 4   LP001013     Yes           0  Not Graduate             2333
# 5   LP001024     Yes           2      Graduate             3200
# 6   LP001027     Yes           2      Graduate             2500
# 7   LP001029      No           0      Graduate             1853
# 8   LP001030     Yes           2      Graduate             1299
# 9   LP001032      No           0      Graduate             4950
# 10  LP001034      No           1  Not Graduate             3596
# 11  LP001036      No           0      Graduate             3510
# 12  LP001038     Yes           0  Not Graduate             4887
# 13  LP001041     Yes           0      Graduate             2600
# ...

# %%
var
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %%
var
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %% [markdown]
#                                                                     Subset

# %%
# var.dropna(subset=["Credit_History"])
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# 13  LP001041    Male     Yes           0      Graduate           NaN
# ...

# %% [markdown]
#                                                                         thresh

# %%
# var.dropna(thresh=1)
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %% [markdown]
#                                                                         Fill Na

# %%
# var.fillna(1)
var
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %%
# var.fillna({
#     "Self_Employed":"yes",
#     "Credit_History":1
# })
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           yes
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %%
# var.fillna(method="ffill")
var
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %% [markdown]
#                                                             ffill(forwardfill) & bfill(Backward_fill)

# %%
# var.fillna(method="ffill")
var
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...

# %%
var.fillna("python",limit=2)
var
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001003    Male     Yes           1      Graduate            No
# 1   LP001005    Male     Yes           0      Graduate           Yes
# 2   LP001006    Male     Yes           0  Not Graduate            No
# 3   LP001008    Male      No           0      Graduate            No
# 4   LP001013    Male     Yes           0  Not Graduate            No
# 5   LP001024    Male     Yes           2      Graduate            No
# 6   LP001027    Male     Yes           2      Graduate           NaN
# 7   LP001029    Male      No           0      Graduate            No
# 8   LP001030    Male     Yes           2      Graduate            No
# 9   LP001032    Male      No           0      Graduate            No
# 10  LP001034    Male      No           1  Not Graduate            No
# 11  LP001036  Female      No           0      Graduate            No
# 12  LP001038    Male     Yes           0  Not Graduate            No
# ...
